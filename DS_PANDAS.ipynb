# %%
#Download the dataset from the given link https://www.kaggle.com/rounakbanik/the-movies-dataset , load the .csv file named as movied_metadata using pandas dataframe and perform following queries:
#1.	Fetch the data of all movied that are rated as adult

import pandas as pd
df = pd.read_csv("D:\\Ali Fawad Hassan\\University\\6th Sem\\movies_metadata.csv")

adult = df[df["adult"]==True]
adult
# Out:
# c:\users\ali\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
# 2.	Fetch the data of  all the movied which have status of ‘Canceled’ or ‘Rumored’
canc_rum = df[(df["status"]=="Canceled") | (df["status"]=="Rumored")]
canc_rum
# Out:
#        adult belongs_to_collection budget  \
# 682    False                   NaN      0
# 775    False                   NaN      0
# 1032   False                   NaN      0
# 1478   False                   NaN      0
# 1513   False                   NaN      0
# ...      ...                   ...    ...
# 44655  False                   NaN      0
# 44731  False                   NaN      0
# 45030  False                   NaN      0
# 45109  False                   NaN      0
# 45289  False                   NaN      0
#
#                                                   genres homepage      id  \
# 682    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN   48260
# 775                        [{'id': 18, 'name': 'Drama'}]      NaN   44495
# 1032                       [{'id': 18, 'name': 'Drama'}]      NaN   38191
# 1478                       [{'id': 18, 'name': 'Drama'}]      NaN   59232
# 1513   [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...      NaN   65046
# ...                                                  ...      ...     ...
# 44655  [{'id': 28, 'name': 'Action'}, {'id': 10752, '...      NaN  104473
# 44731                      [{'id': 18, 'name': 'Drama'}]      NaN   49270
# 45030                  [{'id': 16, 'name': 'Animation'}]      NaN   58828
# 45109  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN   63568
# 45289  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN   87229
#
#          imdb_id original_language             original_title  \
# 682    tt0112604                en             Butterfly Kiss
# 775    tt0072362                en       A Very Natural Thing
# 1032   tt0117781                en              The Sunchaser
# 1478   tt0118117                en            The War at Home
# 1513   tt0116930                en              Love Serenade
# ...          ...               ...                        ...
# 44655  tt0223958               NaN      La prise de Tournavos
# 44731  tt0000832                en          A Corner in Wheat
# 45030  tt0190806                en  The Story of Menstruation
# 45109  tt0147806                ru         A Esli Eto Lyubov?
# 45289  tt1524553                is                 Kóngavegur
#
#                                                 overview  ... release_date  \
# 682    Eunice is walking along the highways of northe...  ...   1995-08-18
# 775    When David, an ex-monk still in his twenties m...  ...   1974-01-01
# 1032   A young half-Navajo convict (Jon Seda) dying o...  ...   1996-05-29
# 1478   Jeremy Collier is a Vietnam veteran who has re...  ...   1996-11-20
# 1513   Ken Sherry, a radio personality from Brisbane,...  ...   1996-10-10
# ...                                                  ...  ...          ...
# 44655  Three military men, seen inside a fortificatio...  ...   1897-01-01
# 44731  A greedy tycoon decides, on a whim, to corner ...  ...   1909-12-13
# 45030  A basic explanation of the purpose and process...  ...   1946-10-18
# 45109  High school students Ksenya and Boris are in l...  ...   1961-06-06
# 45289  After 3 years abroad Junior returns to Iceland...  ...   2010-03-26
#
#       revenue runtime                              spoken_languages   status  \
# 682       0.0    88.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 775       0.0    80.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 1032      0.0   122.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 1478      0.0   119.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 1513      0.0   101.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# ...       ...     ...                                           ...      ...
# 44655     0.0     1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Rumored
# 44731     0.0    14.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 45030     0.0    10.0      [{'iso_639_1': 'en', 'name': 'English'}]  Rumored
# 45109     0.0   102.0      [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Rumored
# 45289     0.0    99.0     [{'iso_639_1': 'is', 'name': 'Íslenska'}]  Rumored
#
#                                                  tagline  \
# 682                                                  NaN
# 775                                                  NaN
# 1032   It began as a kidnapping. It became a journey ...
# 1478                 There Is A Secret About To Explode.
# 1513   Two sisters will do anything to hook the right...
# ...                                                  ...
# 44655                                                NaN
# 44731                                                NaN
# 45030                                                NaN
# 45109                                                NaN
# 45289                               When you are strange
#
#                             title  video vote_average vote_count
# 682                Butterfly Kiss  False          7.4        5.0
# 775          A Very Natural Thing  False          6.3        3.0
# 1032                The Sunchaser  False          6.1        8.0
# 1478              The War at Home  False          6.9        7.0
# 1513                Love Serenade  False          6.0        4.0
# ...                           ...    ...          ...        ...
# 44655  The Surrender of Tournavos  False          4.6        5.0
# 44731           A Corner in Wheat  False          6.5       17.0
# 45030   The Story of Menstruation  False          6.0        8.0
# 45109   But What If This Is Love?  False          5.0        1.0
# 45289                 King's Road  False          0.0        0.0
#
# [232 rows x 24 columns]

# %%
# 3.	Fetch the data of all the movied which has the vote_count of below 100.
vote_count = df[df["vote_count"]<100]
vote_count
# Out:
#        adult                              belongs_to_collection    budget  \
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 7      False                                                NaN         0
# 13     False                                                NaN  44000000
# 25     False                                                NaN         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 13     [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 25                         [{'id': 18, 'name': 'Drama'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 7                                       NaN   45325  tt0112302
# 13                                      NaN   10858  tt0113987
# 25                                      NaN   16420  tt0114057
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 2                    en     Grumpier Old Men
# 3                    en    Waiting to Exhale
# 7                    en         Tom and Huck
# 13                   en                Nixon
# 25                   en              Othello
# ...                 ...                  ...
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview  ... release_date  \
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 7      A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 13     An all-star cast powers this epic look at Amer...  ...   1995-12-22
# 25     The evil Iago pretends to be friend of Othello...  ...   1995-12-15
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#           revenue runtime                                   spoken_languages  \
# 2             0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3      81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7             0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 13     13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 25            0.0   123.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...           ...     ...                                                ...
# 45461         0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462         0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463         0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464         0.0    87.0                                                 []
# 45465         0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 7      Released                             The Original Bad Boys.
# 13     Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 25     Released                    Envy, greed, jealousy and love.
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                      title  video vote_average vote_count
# 2         Grumpier Old Men  False          6.5       92.0
# 3        Waiting to Exhale  False          6.1       34.0
# 7             Tom and Huck  False          5.4       45.0
# 13                   Nixon  False          7.1       72.0
# 25                 Othello  False          7.0       33.0
# ...                    ...    ...          ...        ...
# 45461               Subdue  False          4.0        1.0
# 45462  Century of Birthing  False          9.0        3.0
# 45463             Betrayal  False          3.8        6.0
# 45464     Satan Triumphant  False          0.0        0.0
# 45465             Queerama  False          0.0        0.0
#
# [39405 rows x 24 columns]

# %%
# 4.	Fetch the data of all the movied which has the vote_count of 500 and above and have status of ‘Released’.

rel_500 = df[(df["vote_count"]==500) & (df["status"]=="Released") ]
rel_500
# Out:
#        adult                              belongs_to_collection    budget  \
# 2315   False                                                NaN  15000000
# 2528   False  {'id': 8537, 'name': 'Superman Collection', 'p...  39000000
# 3554   False                                                NaN     10000
# 6614   False                                                NaN  40000000
# 7007   False                                                NaN   8000000
# 14875  False  {'id': 222634, 'name': 'Tooth Fairy Collection...  48000000
# 27924  False                                                NaN  14000000
#
#                                                   genres homepage     id  \
# 2315   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN   9276
# 2528   [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...      NaN   9531
# 3554   [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN    985
# 6614   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN   7288
# 7007   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN    504
# 14875  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...      NaN  23023
# 27924                   [{'id': 53, 'name': 'Thriller'}]      NaN  72784
#
#          imdb_id original_language original_title  \
# 2315   tt0133751                en    The Faculty
# 2528   tt0086393                en   Superman III
# 3554   tt0074486                en     Eraserhead
# 6614   tt0266489                en         Duplex
# 7007   tt0340855                en        Monster
# 14875  tt0808510                en    Tooth Fairy
# 27924  tt1850397                en       The Loft
#
#                                                 overview  ... release_date  \
# 2315   When some very creepy things start happening a...  ...   1998-12-25
# 2528   Aiming to defeat the Man of Steel, wealthy exe...  ...   1983-06-17
# 3554   Henry Spencer tries to survive his industrial ...  ...   1977-03-19
# 6614   When a young couple buys their dream home, the...  ...   2003-09-26
# 7007   Aileen Wuornos is an emotionally scarred highw...  ...   2003-11-16
# 14875  When minor-league hockey player Derek Thompson...  ...   2010-01-14
# 27924  For five men, the opportunity to share a penth...  ...   2014-10-14
#
#            revenue runtime                                   spoken_languages  \
# 2315    40283321.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2528    75850624.0   125.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 3554     7000000.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6614    19322135.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7007    60378584.0   110.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14875  112462508.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 27924   10076790.0   108.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 2315   Released                           Take me to your teacher.
# 2528   Released  If the world's most powerful computer can cont...
# 3554   Released                       Where your nightmares end...
# 6614   Released                                                NaN
# 7007   Released          The first female serial killer of America
# 14875  Released                        You can't handle the tooth.
# 27924  Released                       The right place to do wrong.
#
#               title  video vote_average vote_count
# 2315    The Faculty  False          6.2      500.0
# 2528   Superman III  False          5.3      500.0
# 3554     Eraserhead  False          7.5      500.0
# 6614         Duplex  False          5.9      500.0
# 7007        Monster  False          7.0      500.0
# 14875   Tooth Fairy  False          5.2      500.0
# 27924      The Loft  False          6.4      500.0
#
# [7 rows x 24 columns]

# %%
# 5. Display all the movied who are not  categorised as adult  and have vote_average above or equal to 7
adu_avg = df[(df["adult"]==True) & (df["vote_average"]<=7)]
adu_avg
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
# 6.	Fetch the data of all the movies who have runtime of greater than 200 minutes
run_time = df[(df["runtime"]<200)]
run_time
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45461  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45460                                   NaN   30840  tt0102797
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45461                fa                      رگ خواب
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45460  Yet another version of the classic epic, with ...  ...   1991-05-13
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45460          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45460  Released                                                NaN
# 45461  Released         Rising and falling between a man and woman
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45460                   Robin Hood  False          5.7       26.0
# 45461                       Subdue  False          4.0        1.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [44851 rows x 24 columns]

# %%
# 7.	Print the overviews and title of the movies having vote_average higher 8
vt_avg =df[df["vote_average"]<8]
vt_avg[['title', 'overview']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45460                   Robin Hood
# 45461                       Subdue
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                 overview
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45460  Yet another version of the classic epic, with ...
# 45461        Rising and falling between a man and woman.
# 45463  When one of her hits goes wrong, a professiona...
# 45464  In a small town live two brothers, one a minis...
# 45465  50 years after decriminalisation of homosexual...
#
# [43565 rows x 2 columns]
